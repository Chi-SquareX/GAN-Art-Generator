# %% [markdown]
# # Art generating GAN
#
# A Generative Adversarial Network for generating new art

# %% [markdown]
# # Import required libraries

# %%
import os

# Keras functions
import tensorflow as tf
import keras
from keras.optimizers import *
from keras.models import Sequential, Model, load_model
from keras.layers import *
from matplotlib import pyplot
from IPython.display import clear_output

# Numpy functions
import numpy as np
from numpy.random import *
from numpy import *

#Torchvision for fast and easy loading and resizing
import torchvision
import torchvision.transforms as transforms

from PIL import Image

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
#cd drive/MyDrive/GAN_art/GANGogh
# %cd '/content/drive/MyDrive/Project/WGAN art/dataset_updated'
# Out:
# /content/drive/MyDrive/Project/WGAN art/dataset_updated

# %%
ls
# Out:
# training_data.npy  training_set/  validation_data.npy  validation_set/

# %% [markdown]
# # Load and pre-process the data

# %%
dataset_path = "training_set/"
#dataset_path = "/content/drive/Shareddrives/Disk1/WGANs art/GANGogh/images/figurative/"
#dataset_path = "./images/figurative/"
saved_path = 'training_data.npy'

WIDTH = 64
HEIGHT = 64
IMG_SIZE = (WIDTH,HEIGHT)
EPOCHS = 250

#Look for saved file to save time loading and processing images between runs
print("Looking for previously saved file...")

if not os.path.isfile(saved_path):

    print("\n File not found, loading new data...\n")
    dataset = []
    transform_ds = transforms.Compose([transforms.Resize(IMG_SIZE),]) #define transformation
    
    image_folder = torchvision.datasets.ImageFolder(root=dataset_path,
                                     transform=transform_ds)

    print('Number of artworks found: ',len(image_folder))
    
    
    print("Converting images, this will take a few minutes")
    for i in range (len(image_folder)):
      try:
        image_array = numpy.array(image_folder[i][0])
        dataset.append(image_array)
        if (i%500 == 0):
            print("Pictures processed: ", i)
      except:
        continue

    print("Saving dataset binary file...")
    dataset = np.array(dataset, dtype=np.float32)
    dataset = (dataset - 127.5) / 127.5 #Normalize to [-1 , 1]
    numpy.save(saved_path, dataset)  #Save processed images as npy file

else:
    print("Data found, loading..")
    dataset = np.load(saved_path) 

print("Dataset length: ", len(dataset))
# Out:
# Looking for previously saved file...
# Data found, loading..
# Dataset length:  7938

# %%
dataset_val_path = "validation_set/"
#dataset_path = "/content/drive/Shareddrives/Disk1/WGANs art/GANGogh/images/figurative/"
#dataset_path = "./images/figurative/"
saved_val_path = 'validation_data.npy'

#Look for saved file to save time loading and processing images between runs
print("Looking for previously saved file...")

if not os.path.isfile(saved_val_path):

    print("\n File not found, loading new data...\n")
    val_dataset = []
    val_transform_ds = transforms.Compose([transforms.Resize(IMG_SIZE),]) #define transformation
    
    val_image_folder = torchvision.datasets.ImageFolder(root=dataset_val_path,
                                     transform=val_transform_ds)

    print('Number of artworks found: ',len(val_image_folder))
    
    
    print("Converting images, this will take a few minutes")
    for i in range (len(val_image_folder)):
      try:
        val_image_array = numpy.array(val_image_folder[i][0])
        val_dataset.append(val_image_array)
        if (i%500 == 0):
            print(val_image_folder[i][1])
            print("Pictures processed: ", i)
      except:
        continue
            
    print("Saving dataset binary file...")
    val_dataset = np.array(val_dataset, dtype=np.float32)
    val_dataset = (val_dataset - 127.5) / 127.5 #Normalize to [-1 , 1]
    numpy.save(saved_val_path, val_dataset)  #Save processed images as npy file

else:
    print("Data found, loading..")
    val_dataset = np.load(saved_val_path) 

print("Dataset length: ", len(val_dataset))
# Out:
# Looking for previously saved file...
# Data found, loading..
# Dataset length:  856

# %% [markdown]
# Confirm that the images are the correct shape.

# %%
dataset[3].shape
# Out:
# (64, 64, 3)

# %%
#Use a TensorFlow Dataset to manage the images for easy shuffling, dividing etc
BATCH_SIZE = 32

training_dataset = tf.data.Dataset.from_tensor_slices(dataset).shuffle(9000).batch(BATCH_SIZE)
validation_dataset = tf.data.Dataset.from_tensor_slices(val_dataset).shuffle(9000).batch(BATCH_SIZE)

# %% [markdown]
# # Explore the data

# %% [markdown]
# Here, we'll check out the dataset and what it looks like

# %%
import pandas as pd

#artists = pd.read_csv('best_artworks/artists.csv')
#artists

# %% [markdown]
# There's some data that we dont really need for this task, like their nationality, wikipedia page and bio. Below, we filter the data to more clearly see the artists along with their corresponding genre and number of paintings in a more compact manner. As you can see, we have quite the mix of genres which will hopefully give our model a good base to generate from.

# %%
#artists[['name','genre','paintings']]

# %% [markdown]
# Here we can check out the top 5 genres and artists

# %%
#top_genres = artists['genre'].value_counts()
#top_genres[:5]

# %% [markdown]
# ****Note: These genres are only sorted from the number of artists belonging to that genre, not the number of paintings.****

# %% [markdown]
# We'll sort the list of artists by number of paintings instead to get a better overview of which artist has the most painings in the dataset.

# %%
#no_of_paintings = artists[['name','paintings','genre']].sort_values(ascending=False, by='paintings')
#no_of_paintings

# %% [markdown]
# Van Gogh has been busy I see! Lets try printing some of the paintings to see what we're dealing with.

# %%
import matplotlib.pyplot as plt
import random

np.random.shuffle(dataset) #Shuffle the images
np.random.shuffle(val_dataset) #Shuffle the images

fig = plt.figure(figsize=(12,12))
for i in range(1,37):
    fig.add_subplot(6,6,i)
    plt.imshow(dataset[i])
    plt.axis('off')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# **Beautiful!**
# There's some distortion from the rescaling and they look all weird normalized, this is due to plt.imshow only displaying ranges [0,1] and these are normalized to [-1,1] . If we were to not normalize them at the beginning they would look normal.

# %% [markdown]
# # Build the models

# %% [markdown]
# The generator will take in a random seed and generate an image from that seed, upsampling as much as needed. Note that increasing resolution will require retuning of the models as well as increase training time by a lot. I found that the generator needs to have quite a lot of capacity in order to keep up with the discriminator at later stages of training.
#
# architecture based on the findings and guidelines proposed in the paper:
#
# * Replace any pooling layers with strided convolutions (discriminator) and fractional-strided convolutions (generator).
# * Use batchnorm in both the generator and the discriminator.
# * Remove fully connected hidden layers for deeper architectures
# * Use ReLU activation in generator for all layers except for the output, which uses Tanh.
# * Use LeakyReLU activation in the discriminator for all layers.
#
# Further increasing conv layers will lead to mode collapse from what I've tried

# %%
def build_generator(seed_size, channels):
    
    model = Sequential()

    model.add(Dense(64*64,activation="relu",input_dim=seed_size)) #64x64 units
    model.add(Reshape((4,4,256)))

    model.add(UpSampling2D())
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))
    
    model.add(UpSampling2D())
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))
    
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))
   
    # Optional additional upsampling goes here
    model.add(UpSampling2D(size = (2,2))) #4,4 for 128x128, 2,2 for 64x64
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))

    model.add(UpSampling2D(size=(2,2)))
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))

    model.add(Conv2D(channels,kernel_size=3,padding="same"))
    model.add(Activation("tanh"))
    
    return model

# %% [markdown]
# The discriminator is simply a CNN based image classifier which will output values of what it thinks is fake or real with 0 being fake and 1 being real

# %%
def build_discriminator(image_shape):
    model = Sequential()

    model.add(Conv2D(32, kernel_size=3, strides=2, input_shape=image_shape, 
                     padding="same"))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(64, kernel_size=3, strides=2, padding="same"))
    model.add(ZeroPadding2D(padding=((0,1),(0,1))))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(128, kernel_size=3, strides=2, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(256, kernel_size=3, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(512, kernel_size=3, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(1, activation='sigmoid'))
    
    return model

# %% [markdown]
# Here we use the untrained generator to generate an image (which will be very random)

# %%
SEED_SIZE = 100
IMAGE_CHANNELS = 3

generator = build_generator(SEED_SIZE,IMAGE_CHANNELS)

noise = tf.random.normal([1,SEED_SIZE])
generated_image = generator(noise,training=False)

plt.imshow(generated_image[0, :, :, 0])

# %% [markdown]
# Classify this random image with the untrained discriminator, the prediction will likely be 50%

# %%
image_shape = (HEIGHT, HEIGHT, IMAGE_CHANNELS)

discriminator = build_discriminator(image_shape)
decision = discriminator(generated_image)
print(decision)
# Out:
# tf.Tensor([[0.4998593]], shape=(1, 1), dtype=float32)

# %% [markdown]
# # Define loss functions for the models

# %% [markdown]
# **The discriminators loss** is based on its ability to distinguish real images from fakes. It compares its predictions on real images to an array of ones (remember 1 being real) and its predictions on fake images to an array of zeros (0 being fake). The goal is to classify all real images as 1 and all fakes as 0. The total loss is then these two losses added together.
#
# **The generators loss** is a measurement of how good it performed at fooling the discriminator. If the discriminator classifies the fake images as 1, the generator did a good job.

# %%
cross_entropy = tf.keras.losses.BinaryCrossentropy()

def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# %% [markdown]
# The two models optimizers are separated because we train them separately. I found a slightly lower generator LR to be beneficial.
#
# Beta value of 0.5 generated more stable models as per the findings in the paper "Unsupervised representation learning with deep convolutional generative adversarial networks"

# %%
generator_optimizer = tf.keras.optimizers.Adam(1e-5, 0.001)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-5, 0.001)

# %% [markdown]
# # Function for saving the generated images

# %%
GENERATED_ROWS = 7
GENERATED_COLS = 7
MARGIN = 2 # Give the images a little frame

def save_images(cnt, noise):
    #Define the "base" of the saved image as a big black canvas
    image_array = np.full(( 
      MARGIN + (GENERATED_ROWS * (WIDTH + MARGIN)), 
      MARGIN + (GENERATED_COLS * (HEIGHT + MARGIN)), 3), 
      0, dtype=np.uint8)
    
    generated_images =  generator.predict(noise)
    
    image_count = 0
    for row in range(GENERATED_ROWS):
        for col in range(GENERATED_COLS):
            r = row * (WIDTH + 2) + MARGIN
            c = col * (HEIGHT + 2) + MARGIN
            image_array[r:r+WIDTH , c:c+HEIGHT] = generated_images[image_count] * 127.5 + 127.5
            image_count += 1
            
    output_path  = os.path.join("/kaggle/working/generated2/")
    if not os.path.exists(output_path):
        os.makedirs(output_path)
        
    filename = os.path.join(output_path,f"train-{cnt}.png")
    im = Image.fromarray(image_array)
    im.save(filename)

# %% [markdown]
# # Train the models
#
# The training begins by providing a random seed to the generator, which is then used to generate an image. The discriminator then classifies images from both the fake and real dataset. The loss is calculated separately for each model and the gradients are updated.
#
# Based on the TensorFlow DCGAN tutorial

# %%
# This goes a bit deeper "behind the scenes" and manually sets the gradients
# instead of letting Keras and TensorFlow set it automatically. This is because
# the two models need to be trained separately
@tf.function
def train_step(images):
    seed = tf.random.normal([BATCH_SIZE, SEED_SIZE])
    
    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        generated_images = generator(seed, training = True)
        
        real_output = discriminator(images, training=True)
        fake_output = discriminator(generated_images, training=True)
        
        gen_loss = generator_loss(fake_output)
        disc_loss = discriminator_loss(real_output, fake_output)

        gradients_of_generator = gen_tape.gradient(
            gen_loss,
            generator.trainable_variables
        )
        gradients_of_discriminator = disc_tape.gradient(
            disc_loss, 
            discriminator.trainable_variables
        )
        
        generator_optimizer.apply_gradients(zip(gradients_of_generator,
                                                generator.trainable_variables))
        
        discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, 
                                                    discriminator.trainable_variables))

        return gen_loss, disc_loss

# %%
def val_step(images):
  seed = tf.random.normal([BATCH_SIZE, SEED_SIZE])
  with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
    generated_images = generator(seed, training = True)
    
    real_output = discriminator(images, training=True)
    fake_output = discriminator(generated_images, training=True)

    gen_loss = generator_loss(fake_output)
    disc_loss = discriminator_loss(real_output, fake_output)
    return gen_loss, disc_loss

def val(dataset, epoch,fixed_seed):
  gen_loss_list = []
  disc_loss_list = []
  for image_batch in dataset:
      t = val_step(image_batch)
      gen_loss_list.append(t[0])
      disc_loss_list.append(t[1])
      
  g_loss = sum(gen_loss_list) / len(gen_loss_list) #calculate losses
  d_loss = sum(disc_loss_list) / len(disc_loss_list)
  
  print(f'VAL gen loss = {g_loss}, disc loss = {d_loss}')
  
  save_images(epoch, fixed_seed)
  return g_loss,d_loss

# %%
def train(dataset, epochs):
    # Use a fixed seed for the saved images so we can watch their development
    fixed_seed = np.random.normal(0, 1, (GENERATED_ROWS * GENERATED_COLS, SEED_SIZE))
    g_loss=[]
    d_loss=[]
    loss=[]
    val_g_loss=[]
    val_d_loss=[]
    val_loss=[]

    for epoch in range(epochs):
        gen_loss_list = []
        disc_loss_list = []
        acc_list = []
        for image_batch in dataset:
            t = train_step(image_batch)
            gen_loss_list.append(t[0])
            disc_loss_list.append(t[1])
            
        g_loss.append(sum(gen_loss_list) / len(gen_loss_list)) #calculate losses
        d_loss.append(sum(disc_loss_list) / len(disc_loss_list))
        loss.append((g_loss[epoch]+d_loss[epoch])/2)
        
        print(f'Epoch {epoch}, gen loss = {g_loss[epoch]}, disc loss = {d_loss[epoch]}')
        
        v = val(validation_dataset,epoch,fixed_seed)
        val_g_loss.append(v[0]) #calculate losses
        val_d_loss.append(v[1])
        val_loss.append((val_d_loss[epoch]+val_g_loss[epoch])/2)
        
        save_images(epoch, fixed_seed)
    return g_loss,d_loss,loss,val_g_loss,val_d_loss,val_loss

# %% [markdown]
# Train the models, ideally we want to see the losses hovering at around the same values, indicating that they are both improving at similar rates

# %%
hist=train(training_dataset, EPOCHS)
# Out:
# Epoch 0, gen loss = 1.2353580582094001, disc loss = 1.1192376929593373
# VAL gen loss = 0.9466899589256004, disc loss = 1.1559744234438296
# Epoch 1, gen loss = 1.4533989228397968, disc loss = 0.9697152869289659
# VAL gen loss = 1.5191841125488281, disc loss = 1.1203022709599249
# Epoch 2, gen loss = 1.4599322583301957, disc loss = 1.0435033591396838
# VAL gen loss = 1.6078486972384982, disc loss = 0.7070701740406178
# Epoch 3, gen loss = 1.4366817857366967, disc loss = 1.0163151997638993
# VAL gen loss = 1.6028381630226418, disc loss = 0.765111004864728
# Epoch 4, gen loss = 1.4181827407285392, disc loss = 0.9629659384608747
# VAL gen loss = 1.103584854691117, disc loss = 0.99125282852738
# Epoch 5, gen loss = 1.453451133636107, disc loss = 0.8849532652092746
# VAL gen loss = 1.3520003424750433, disc loss = 0.7950417553936994
# Epoch 6, gen loss = 1.5384072912744728, disc loss = 0.7963212101335028
# VAL gen loss = 1.3214166429307725, disc loss = 0.866167633621781
# Epoch 7, gen loss = 1.3301595052083333, disc loss = 0.9934092448897152
# VAL gen loss = 0.8255180076316551, disc loss = 1.2010561625162761
# Epoch 8, gen loss = 1.0313577307275978, disc loss = 1.3180352023327686
# VAL gen loss = 0.9216178611472801, disc loss = 1.451606891773365
# Epoch 9, gen loss = 1.0602642503608182, disc loss = 1.289316200348268
# VAL gen loss = 1.0507373103389033, disc loss = 1.2503077189127605
# Epoch 10, gen loss = 1.1696350833019578, disc loss = 1.154146002957141
# VAL gen loss = 1.3491431342230902, disc loss = 1.124603200841833
# Epoch 11, gen loss = 1.2136929063911897, disc loss = 1.1302875074516818
# VAL gen loss = 1.251713788067853, disc loss = 1.2065442403157551
# Epoch 12, gen loss = 1.194577872035015, disc loss = 1.150940799330133
# VAL gen loss = 1.0148529476589627, disc loss = 1.263893551296658
# Epoch 13, gen loss = 1.1543820545855297, disc loss = 1.1992550279241967
# VAL gen loss = 1.0755668216281467, disc loss = 1.3334019978841145
# Epoch 14, gen loss = 1.0238638268895897, disc loss = 1.3388724576038529
# VAL gen loss = 0.747640397813585, disc loss = 1.4806884483054832
# Epoch 15, gen loss = 0.9969457909764057, disc loss = 1.3530136169678715
# VAL gen loss = 0.9109663080286097, disc loss = 1.3340979682074652
# Epoch 16, gen loss = 1.0040257465408509, disc loss = 1.3199505786819152
# VAL gen loss = 1.0127136795609086, disc loss = 1.330102143464265
# Epoch 17, gen loss = 0.9823398207086157, disc loss = 1.327467585184488
# VAL gen loss = 0.8682142187047888, disc loss = 1.3496499238190827
# Epoch 18, gen loss = 0.9829303174612513, disc loss = 1.330381094691265
# VAL gen loss = 0.8049738848650897, disc loss = 1.3921202200430411
# Epoch 19, gen loss = 0.9800616651175013, disc loss = 1.3327569310444904
# VAL gen loss = 0.8804226628056279, disc loss = 1.3769810994466145
# Epoch 20, gen loss = 0.9528838008283133, disc loss = 1.3513600299636044
# VAL gen loss = 0.9919172216344763, disc loss = 1.359624085602937
# Epoch 21, gen loss = 0.9681436929358057, disc loss = 1.3211995932950553
# VAL gen loss = 1.0862840016682942, disc loss = 1.360884913691768
# Epoch 22, gen loss = 0.9787505123031187, disc loss = 1.2935783661991718
# VAL gen loss = 0.8712613847520616, disc loss = 1.3098906057852286
# Epoch 23, gen loss = 0.9998751720750189, disc loss = 1.273740469691265
# VAL gen loss = 0.893402099609375, disc loss = 1.2821567676685475
# Epoch 24, gen loss = 0.9850954109406376, disc loss = 1.2860803565825802
# VAL gen loss = 0.8617565720169632, disc loss = 1.290949786150897
# Epoch 25, gen loss = 0.9873733214106426, disc loss = 1.2751784726797817
# VAL gen loss = 0.8560676574707031, disc loss = 1.3159736350730613
# Epoch 26, gen loss = 1.0083434936033195, disc loss = 1.24687629914188
# VAL gen loss = 0.8785189875849971, disc loss = 1.2693912364818432
# Epoch 27, gen loss = 1.0045577206286083, disc loss = 1.267447352888115
# VAL gen loss = 0.8573915693495009, disc loss = 1.301637437608507
# Epoch 28, gen loss = 1.0216718313684425, disc loss = 1.225410675906752
# VAL gen loss = 0.9199806495949074, disc loss = 1.2804750513147425
# Epoch 29, gen loss = 1.0107181656312751, disc loss = 1.2510894407708961
# VAL gen loss = 0.8851428561740451, disc loss = 1.2660364221643519
# Epoch 30, gen loss = 1.0333104880459338, disc loss = 1.227228248933233
# VAL gen loss = 1.0705865930627894, disc loss = 1.1946624473289207
# Epoch 31, gen loss = 1.0556029047831952, disc loss = 1.213357948395143
# VAL gen loss = 0.7338278735125506, disc loss = 1.2897478739420574
# Epoch 32, gen loss = 1.0380788289878262, disc loss = 1.2261119674008534
# VAL gen loss = 1.2309125264485676, disc loss = 1.2958772447374132
# Epoch 33, gen loss = 1.0418606800247867, disc loss = 1.2182548553589359
# VAL gen loss = 1.0414100223117404, disc loss = 1.2793945029929832
# Epoch 34, gen loss = 1.0550102019405747, disc loss = 1.2288636969754017
# VAL gen loss = 0.8911567970558449, disc loss = 1.2484029134114583
# Epoch 35, gen loss = 1.055379844573607, disc loss = 1.2154931983794552
# VAL gen loss = 1.1845375343605324, disc loss = 1.2965144404658564
# Epoch 36, gen loss = 1.051405573465738, disc loss = 1.2193419674792922
# VAL gen loss = 1.021007325914171, disc loss = 1.2541077225296586
# Epoch 37, gen loss = 1.0470828627008033, disc loss = 1.2186105260887299
# VAL gen loss = 1.1866802639431424, disc loss = 1.3238887080439814
# Epoch 38, gen loss = 1.0430199803118725, disc loss = 1.244292354966742
# VAL gen loss = 0.7905568016899956, disc loss = 1.32738282945421
# Epoch 39, gen loss = 1.0178032687390186, disc loss = 1.245834779547879
# VAL gen loss = 1.135487026638455, disc loss = 1.2512885199652777
# Epoch 40, gen loss = 1.0411378178730548, disc loss = 1.2195174741936496
# VAL gen loss = 1.1434657485396773, disc loss = 1.2843674553765192
# Epoch 41, gen loss = 1.0404670439570782, disc loss = 1.2283122970397213
# VAL gen loss = 0.9709155471236618, disc loss = 1.2200116757993344
# Epoch 42, gen loss = 1.0343710045259162, disc loss = 1.2286954213337726
# VAL gen loss = 1.0201005582456235, disc loss = 1.2528042263454862
# Epoch 43, gen loss = 1.0415713145550953, disc loss = 1.2341575775759288
# VAL gen loss = 0.9512492992259838, disc loss = 1.2676706667299624
# Epoch 44, gen loss = 1.0519707001835468, disc loss = 1.2073105655042042
# VAL gen loss = 0.9942537943522135, disc loss = 1.2759691874186199
# Epoch 45, gen loss = 1.0448749343075427, disc loss = 1.2335317833835342
# VAL gen loss = 0.9823473471182363, disc loss = 1.2810132061993633
# Epoch 46, gen loss = 1.0178350732029682, disc loss = 1.245127237465487
# VAL gen loss = 1.1539940304226346, disc loss = 1.3741723519784432
# Epoch 47, gen loss = 1.0217560917498119, disc loss = 1.253341245842746
# VAL gen loss = 1.0274555065013744, disc loss = 1.3689329359266493
# Epoch 48, gen loss = 0.9898507604637299, disc loss = 1.2780282506981049
# VAL gen loss = 0.8231640568485966, disc loss = 1.26677166974103
# Epoch 49, gen loss = 1.0183344461831703, disc loss = 1.2362697861759537
# VAL gen loss = 1.201208609121817, disc loss = 1.2517563148781106
# Epoch 50, gen loss = 1.0282005708380397, disc loss = 1.242246819308484
# VAL gen loss = 1.035797048498083, disc loss = 1.2462563691315827
# Epoch 51, gen loss = 1.0232396872646838, disc loss = 1.2250323314743348
# VAL gen loss = 0.9136076326723452, disc loss = 1.219349190040871
# Epoch 52, gen loss = 1.0216437037211346, disc loss = 1.2224501031469628
# VAL gen loss = 1.0720986966733579, disc loss = 1.2603638260452836
# Epoch 53, gen loss = 1.064289629220005, disc loss = 1.1640480378545432
# VAL gen loss = 0.8816312860559534, disc loss = 1.356212333396629
# Epoch 54, gen loss = 1.0234533715918361, disc loss = 1.2324126829583961
# VAL gen loss = 0.8990501121238426, disc loss = 1.2609543976960358
# Epoch 55, gen loss = 1.0336095357994477, disc loss = 1.21987694430064
# VAL gen loss = 1.0893847854049117, disc loss = 1.2274116233543113
# Epoch 56, gen loss = 1.0471681648468876, disc loss = 1.2034684146743222
# VAL gen loss = 0.9711702841299551, disc loss = 1.2897061948423032
# Epoch 57, gen loss = 1.0365419196316517, disc loss = 1.2071356715926205
# VAL gen loss = 1.088114067360207, disc loss = 1.1874156528049045
# Epoch 58, gen loss = 1.034949612904744, disc loss = 1.1983399908226657
# VAL gen loss = 1.1840525026674624, disc loss = 1.1974839104546442
# Epoch 59, gen loss = 1.0340875219628514, disc loss = 1.2124920580760543
# VAL gen loss = 1.1474104987250433, disc loss = 1.236394105134187
# Epoch 60, gen loss = 1.031455779171373, disc loss = 1.2138233108214107
# VAL gen loss = 1.006924452605071, disc loss = 1.2474951567473236
# Epoch 61, gen loss = 1.0411349989802963, disc loss = 1.1990725352582203
# VAL gen loss = 0.8150371975368924, disc loss = 1.2536129421657987
# Epoch 62, gen loss = 1.0606995854511798, disc loss = 1.1799622807636798
# VAL gen loss = 1.0606281139232494, disc loss = 1.222637035228588
# Epoch 63, gen loss = 1.0366278345805096, disc loss = 1.2094306179797314
# VAL gen loss = 1.0394563321714048, disc loss = 1.3001792342574507
# Epoch 64, gen loss = 1.035807169106112, disc loss = 1.2047239249968624
# VAL gen loss = 0.7665057712131076, disc loss = 1.3110453287760417
# Epoch 65, gen loss = 1.0384036144578312, disc loss = 1.1902934001631527
# VAL gen loss = 1.1591902132387515, disc loss = 1.323104151973018
# Epoch 66, gen loss = 1.0762336455195782, disc loss = 1.1562095550169427
# VAL gen loss = 0.9433680640326606, disc loss = 1.3478300306532118
# Epoch 67, gen loss = 1.0509877645347012, disc loss = 1.2041563470679593
# VAL gen loss = 0.8156692363597728, disc loss = 1.2305076033980757
# Epoch 68, gen loss = 1.0401922631933986, disc loss = 1.1942128867030624
# VAL gen loss = 1.1796105702718098, disc loss = 1.2675097430193867
# Epoch 69, gen loss = 1.0606774019907756, disc loss = 1.1767619795588604
# VAL gen loss = 0.9588218265109592, disc loss = 1.1935936256691262
# Epoch 70, gen loss = 1.049138080642884, disc loss = 1.1807865004941642
# VAL gen loss = 0.9902596650300203, disc loss = 1.235404403121383
# Epoch 71, gen loss = 1.0725445728225402, disc loss = 1.1503477288058483
# VAL gen loss = 1.2879337734646268, disc loss = 1.2647662692599826
# Epoch 72, gen loss = 1.0317020033258033, disc loss = 1.2038797278959588
# VAL gen loss = 1.0235453711615667, disc loss = 1.2342347039116754
# Epoch 73, gen loss = 1.0492965514401356, disc loss = 1.1860740079458458
# VAL gen loss = 1.0090793327048972, disc loss = 1.2370005007143374
# Epoch 74, gen loss = 1.0677949836455196, disc loss = 1.1636986177130397
# VAL gen loss = 0.80911417360659, disc loss = 1.3258220531322338
# Epoch 75, gen loss = 1.0262510000941265, disc loss = 1.2083202193539784
# VAL gen loss = 0.8749431327537254, disc loss = 1.1986091048629195
# Epoch 76, gen loss = 1.051350176095005, disc loss = 1.1725135404900853
# VAL gen loss = 1.1812249642831307, disc loss = 1.2198393079969618
# Epoch 77, gen loss = 1.0776710357053212, disc loss = 1.1529643966490963
# VAL gen loss = 0.8805344193070023, disc loss = 1.2219561824092158
# Epoch 78, gen loss = 1.0946071885197037, disc loss = 1.1233252100197666
# VAL gen loss = 0.9771376715766059, disc loss = 1.207080982349537
# Epoch 79, gen loss = 1.0936513387534512, disc loss = 1.1463368120921185
# VAL gen loss = 1.149301528930664, disc loss = 1.1968277825249567
# Epoch 80, gen loss = 1.1399266499592118, disc loss = 1.0896400543580573
# VAL gen loss = 0.9612943154794199, disc loss = 1.1631127816659432
# Epoch 81, gen loss = 1.1367395852943023, disc loss = 1.09842789125251
# VAL gen loss = 1.155636328238028, disc loss = 1.064676426075123
# Epoch 82, gen loss = 1.065831195877259, disc loss = 1.1767139358214107
# VAL gen loss = 1.087188650060583, disc loss = 1.0656806098090277
# Epoch 83, gen loss = 1.084763002204129, disc loss = 1.1406479188237324
# VAL gen loss = 1.208243899875217, disc loss = 1.2290550514503762
# Epoch 84, gen loss = 1.1007249211690513, disc loss = 1.1310240963855422
# VAL gen loss = 0.9051518616852937, disc loss = 1.2461752714934173
# Epoch 85, gen loss = 1.0614072500941265, disc loss = 1.163149178746235
# VAL gen loss = 1.2371415032280817, disc loss = 1.1568614818431713
# Epoch 86, gen loss = 1.0608617330650727, disc loss = 1.1763849832925453
# VAL gen loss = 0.8368516144929109, disc loss = 1.18836099130136
# Epoch 87, gen loss = 1.0731544341428212, disc loss = 1.162252403167357
# VAL gen loss = 1.1549701690673828, disc loss = 1.165743933783637
# Epoch 88, gen loss = 1.1037781497082078, disc loss = 1.1187885085262927
# VAL gen loss = 1.5136891117802374, disc loss = 0.8824837296097366
# Epoch 89, gen loss = 1.104068863344001, disc loss = 1.1225784485598644
# VAL gen loss = 1.2541619760018807, disc loss = 1.1435765160454645
# Epoch 90, gen loss = 1.1383926820563504, disc loss = 1.1013149276794678
# VAL gen loss = 0.8105381859673394, disc loss = 1.2048260724103008
# Epoch 91, gen loss = 1.1751444253576808, disc loss = 1.050340032003012
# VAL gen loss = 1.187048735441985, disc loss = 1.0417115246808086
# Epoch 92, gen loss = 1.1333224744681853, disc loss = 1.1102819481049198
# VAL gen loss = 1.391799079047309, disc loss = 1.1925054479528356
# Epoch 93, gen loss = 1.1815055632686997, disc loss = 1.0506349126976657
# VAL gen loss = 1.0463843169035736, disc loss = 1.095503913031684
# Epoch 94, gen loss = 1.1091505916243098, disc loss = 1.1351311005741718
# VAL gen loss = 1.1271319212736908, disc loss = 1.219734757034867
# Epoch 95, gen loss = 1.1130287752572792, disc loss = 1.1244771566735692
# VAL gen loss = 1.2418458726671007, disc loss = 1.1464471463803891
# Epoch 96, gen loss = 1.1308628066955322, disc loss = 1.1029805256180973
# VAL gen loss = 1.0401743429678458, disc loss = 1.1619219603361908
# Epoch 97, gen loss = 1.1199099376019703, disc loss = 1.1097542023563003
# VAL gen loss = 1.1569059160020616, disc loss = 1.1302531207049336
# Epoch 98, gen loss = 1.1300852825363956, disc loss = 1.1030317559299698
# VAL gen loss = 1.11846598872432, disc loss = 1.1325932961923104
# Epoch 99, gen loss = 1.1840116814915913, disc loss = 1.0615533422753514
# VAL gen loss = 1.4670850965711806, disc loss = 1.1494923344364874
# Epoch 100, gen loss = 1.1887048928134412, disc loss = 1.0610122374262676
# VAL gen loss = 1.0053404348867911, disc loss = 1.107916372793692
# Epoch 101, gen loss = 1.1444635965737953, disc loss = 1.1032223375925578
# VAL gen loss = 0.8082861017297815, disc loss = 1.1607885713930484
# Epoch 102, gen loss = 1.1523658108998494, disc loss = 1.0818118666070533
# VAL gen loss = 1.0503271597403068, disc loss = 1.0737536395037617
# Epoch 103, gen loss = 1.2098994121015312, disc loss = 1.0146247833129391
# VAL gen loss = 1.3906231632939092, disc loss = 1.1011457090024594
# Epoch 104, gen loss = 1.1773544372803715, disc loss = 1.0654855751129517
# VAL gen loss = 1.122568201135706, disc loss = 1.1108712796811704
# Epoch 105, gen loss = 1.1907908734547565, disc loss = 1.0597594234359313
# VAL gen loss = 1.101430892944336, disc loss = 1.098497955887406
# Epoch 106, gen loss = 1.2143282603068524, disc loss = 1.0228571757734062
# VAL gen loss = 1.2191198843496818, disc loss = 1.1165984824851707
# Epoch 107, gen loss = 1.1436997991967872, disc loss = 1.0932365938362827
# VAL gen loss = 1.5137374312789351, disc loss = 1.1655346199318215
# Epoch 108, gen loss = 1.1840089851593876, disc loss = 1.0646014232712098
# VAL gen loss = 1.1055333879258897, disc loss = 1.0570432874891493
# Epoch 109, gen loss = 1.1898720369760292, disc loss = 1.0572741405073418
# VAL gen loss = 1.2121730380588107, disc loss = 1.0350394778781467
# Epoch 110, gen loss = 1.217438602064508, disc loss = 1.0252824040301833
# VAL gen loss = 0.9972336380570023, disc loss = 1.0840367917661313
# Epoch 111, gen loss = 1.2054850260416667, disc loss = 1.0470313872678212
# VAL gen loss = 1.4389854713722512, disc loss = 1.0747547856083624
# Epoch 112, gen loss = 1.2062263948371612, disc loss = 1.0551558038795807
# VAL gen loss = 0.824670155843099, disc loss = 1.1838407163266782
# Epoch 113, gen loss = 1.2169510561778363, disc loss = 1.0414306150382782
# VAL gen loss = 1.3111289695457176, disc loss = 1.099156344378436
# Epoch 114, gen loss = 1.2108225381996738, disc loss = 1.0339605492281627
# VAL gen loss = 1.4926483719437211, disc loss = 1.131355426929615
# Epoch 115, gen loss = 1.2006904571410641, disc loss = 1.0614206091945908
# VAL gen loss = 0.9564315654613353, disc loss = 1.0756517339635778
# Epoch 116, gen loss = 1.2526553969785392, disc loss = 1.014789933660423
# VAL gen loss = 1.2969195048014324, disc loss = 1.0367359585232205
# Epoch 117, gen loss = 1.220141184856614, disc loss = 1.0250575666925514
# VAL gen loss = 1.2116583364981193, disc loss = 1.0770352681477864
# Epoch 118, gen loss = 1.2342189804138428, disc loss = 1.0211616730594253
# VAL gen loss = 1.4698924311885126, disc loss = 1.1764660588017217
# Epoch 119, gen loss = 1.2460317343593124, disc loss = 1.0062045668023658
# VAL gen loss = 1.4690057260018807, disc loss = 1.0742842356363933
# Epoch 120, gen loss = 1.2408905642099648, disc loss = 1.0225662782967808
# VAL gen loss = 0.8903564170554832, disc loss = 1.404738390887225
# Epoch 121, gen loss = 1.2211775569073167, disc loss = 1.0390710792388302
# VAL gen loss = 1.0388123547589336, disc loss = 0.9441362310338903
# Epoch 122, gen loss = 1.2335086194386922, disc loss = 1.0302380174996864
# VAL gen loss = 0.951106036150897, disc loss = 1.0948762540464048
# Epoch 123, gen loss = 1.2184612473330823, disc loss = 1.041672181891629
# VAL gen loss = 1.4217745463053386, disc loss = 1.1238457715069805
# Epoch 124, gen loss = 1.223150659277736, disc loss = 1.0346351225213353
# VAL gen loss = 1.3211005881980613, disc loss = 1.1713896150942202
# Epoch 125, gen loss = 1.2024163548726154, disc loss = 1.0636459411866215
# VAL gen loss = 1.3337556344491464, disc loss = 1.1213807000054254
# Epoch 126, gen loss = 1.2021595905104794, disc loss = 1.0509523445343876
# VAL gen loss = 1.0135436587863498, disc loss = 1.0535546761971932
# Epoch 127, gen loss = 1.2640750992250251, disc loss = 1.002456236077121
# VAL gen loss = 0.9662585081877532, disc loss = 0.9871474372016059
# Epoch 128, gen loss = 1.2341835604135292, disc loss = 1.0271315976797817
# VAL gen loss = 1.2785907321506076, disc loss = 1.0440225954409
# Epoch 129, gen loss = 1.2500188743254268, disc loss = 1.0148750519656753
# VAL gen loss = 0.8086796513310185, disc loss = 1.1899676852756076
# Epoch 130, gen loss = 1.2716566951399348, disc loss = 1.0103239496070218
# VAL gen loss = 1.0107156965467665, disc loss = 1.150866190592448
# Epoch 131, gen loss = 1.2587926167560868, disc loss = 0.9862909278716429
# VAL gen loss = 1.2775438096788194, disc loss = 1.0685809100115742
# Epoch 132, gen loss = 1.245326888609124, disc loss = 1.0116016433899662
# VAL gen loss = 1.1905702661584925, disc loss = 1.1096539673981842
# Epoch 133, gen loss = 1.2249601433076054, disc loss = 1.0431268531155873
# VAL gen loss = 1.0001680586073134, disc loss = 1.0724885022198711
# Epoch 134, gen loss = 1.2289025486712475, disc loss = 1.0289551761734437
# VAL gen loss = 1.1772500497323495, disc loss = 1.0725211390742548
# Epoch 135, gen loss = 1.2418312164674323, disc loss = 1.0147428704074108
# VAL gen loss = 1.2472008599175348, disc loss = 1.0914216218171295
# Epoch 136, gen loss = 1.2849771890295558, disc loss = 0.9898274739583334
# VAL gen loss = 1.2988962244104456, disc loss = 0.9353731649893301
# Epoch 137, gen loss = 1.3091690492438504, disc loss = 0.9883487808656501
# VAL gen loss = 0.9235800283926504, disc loss = 1.149136437310113
# Epoch 138, gen loss = 1.2615233884757782, disc loss = 1.0079527705548756
# VAL gen loss = 1.4821849399142795, disc loss = 1.0852816546404804
# Epoch 139, gen loss = 1.2734776998619477, disc loss = 1.0084914854731426
# VAL gen loss = 0.8254919405336734, disc loss = 1.1578068909821686
# Epoch 140, gen loss = 1.2868021156893197, disc loss = 0.9925111824250126
# VAL gen loss = 0.9156989344844112, disc loss = 1.1127238097014251
# Epoch 141, gen loss = 1.2950488477346886, disc loss = 0.9771836368913153
# VAL gen loss = 1.1695485998083044, disc loss = 1.2363703692400898
# Epoch 142, gen loss = 1.3299196542027485, disc loss = 0.9673638401261295
# VAL gen loss = 1.2404933505588107, disc loss = 1.1115161048041449
# Epoch 143, gen loss = 1.3693222597420933, disc loss = 0.9467438847185617
# VAL gen loss = 0.7059821376094112, disc loss = 1.2723815352828414
# Epoch 144, gen loss = 1.3394090277124122, disc loss = 0.9686817950512989
# VAL gen loss = 0.9441097400806568, disc loss = 1.2885993674949363
# Epoch 145, gen loss = 1.3414355664846886, disc loss = 0.9659127844385353
# VAL gen loss = 0.987600255895544, disc loss = 1.0934263865152996
# Epoch 146, gen loss = 1.3704666076415035, disc loss = 0.9367048884012613
# VAL gen loss = 1.0016226591887298, disc loss = 1.0223465672245733
# Epoch 147, gen loss = 1.3387228111665412, disc loss = 0.9589205822312689
# VAL gen loss = 1.0627786848280165, disc loss = 1.044857519644278
# Epoch 148, gen loss = 1.3107054683578063, disc loss = 0.9770607086549322
# VAL gen loss = 1.0458732887550637, disc loss = 1.230634194833261
# Epoch 149, gen loss = 1.3767713676973519, disc loss = 0.9341677623580259
# VAL gen loss = 1.1799724720142506, disc loss = 1.0212511839690033
# Epoch 150, gen loss = 1.3551747272292294, disc loss = 0.9673870040709713
# VAL gen loss = 0.8148098698368779, disc loss = 1.1373847678855613
# Epoch 151, gen loss = 1.3218925506714359, disc loss = 0.9835529863595005
# VAL gen loss = 1.0806977307354961, disc loss = 1.0441895944100839
# Epoch 152, gen loss = 1.3844974625062751, disc loss = 0.9299517405559738
# VAL gen loss = 1.7923821343315973, disc loss = 1.1472236492015697
# Epoch 153, gen loss = 1.3523913770315636, disc loss = 0.9708080981151167
# VAL gen loss = 1.1027295147931133, disc loss = 1.029451158311632
# Epoch 154, gen loss = 1.351580393840989, disc loss = 0.9563624370528991
# VAL gen loss = 1.3510551452636719, disc loss = 1.0810015643084492
# Epoch 155, gen loss = 1.3118960215863453, disc loss = 0.9828140687751004
# VAL gen loss = 1.2141429759837963, disc loss = 1.0646103046558522
# Epoch 156, gen loss = 1.343661511279493, disc loss = 0.9536225958521586
# VAL gen loss = 1.6335077638979312, disc loss = 1.0415998388219763
# Epoch 157, gen loss = 1.3670583211753262, disc loss = 0.9717335528637989
# VAL gen loss = 0.9577591507523148, disc loss = 1.0325982129132305
# Epoch 158, gen loss = 1.3884733269013554, disc loss = 0.9244194796765186
# VAL gen loss = 1.687378212257668, disc loss = 1.1026395868372034
# Epoch 159, gen loss = 1.3522494519091992, disc loss = 0.9663767374184237
# VAL gen loss = 1.032482005931713, disc loss = 1.0889128225821036
# Epoch 160, gen loss = 1.3366664901794678, disc loss = 0.970793819810492
# VAL gen loss = 1.1053414521393952, disc loss = 1.0638851589626737
# Epoch 161, gen loss = 1.4100556277845757, disc loss = 0.9132140132796812
# VAL gen loss = 1.4434023256655093, disc loss = 0.9547598097059462
# Epoch 162, gen loss = 1.3885836314006024, disc loss = 0.9317242725785956
# VAL gen loss = 1.2611082571524161, disc loss = 1.0012202792697482
# Epoch 163, gen loss = 1.344838582847013, disc loss = 0.9548576385620607
# VAL gen loss = 1.4492376822012443, disc loss = 0.9998041788736979
# Epoch 164, gen loss = 1.3657409177726532, disc loss = 0.9484279893009538
# VAL gen loss = 1.2215230023419414, disc loss = 0.9823137919108073
# Epoch 165, gen loss = 1.3582351868411144, disc loss = 0.9482363045933735
# VAL gen loss = 0.9312980086715134, disc loss = 1.0550258071334273
# Epoch 166, gen loss = 1.4098795082674447, disc loss = 0.9062198501035391
# VAL gen loss = 1.0359346601698134, disc loss = 1.0755962795681424
# Epoch 167, gen loss = 1.4061781795149348, disc loss = 0.9084453046561245
# VAL gen loss = 0.9339284543637876, disc loss = 1.0091298421223958
# Epoch 168, gen loss = 1.5256413838949547, disc loss = 0.8367665608723959
# VAL gen loss = 1.0365885275381583, disc loss = 0.8747327592637804
# Epoch 169, gen loss = 1.4699230270692143, disc loss = 0.8918979139213102
# VAL gen loss = 0.8299484959355107, disc loss = 1.2375708685980902
# Epoch 170, gen loss = 1.4745137777673192, disc loss = 0.8740123457697979
# VAL gen loss = 1.593234450728805, disc loss = 0.9368695859555844
# Epoch 171, gen loss = 1.499663448716742, disc loss = 0.8375497228170494
# VAL gen loss = 1.754132588704427, disc loss = 1.0452859666612413
# Epoch 172, gen loss = 1.5263345863924447, disc loss = 0.8339067941688629
# VAL gen loss = 1.8492069950810186, disc loss = 0.7746548122829862
# Epoch 173, gen loss = 1.512376655057731, disc loss = 0.8672704734955446
# VAL gen loss = 1.6926441899052374, disc loss = 1.0492472472014251
# Epoch 174, gen loss = 1.5230098862245858, disc loss = 0.8479283957117533
# VAL gen loss = 0.7980687883165147, disc loss = 1.102357652452257
# Epoch 175, gen loss = 1.4761840330070282, disc loss = 0.8776161776010292
# VAL gen loss = 1.397716239646629, disc loss = 0.9559098702889902
# Epoch 176, gen loss = 1.4074089326054218, disc loss = 0.9323051483276857
# VAL gen loss = 1.386432788990162, disc loss = 1.0215317055031106
# Epoch 177, gen loss = 1.4693208870638805, disc loss = 0.8787258408634538
# VAL gen loss = 1.1940441838017217, disc loss = 0.9371371092619719
# Epoch 178, gen loss = 1.4241087886703063, disc loss = 0.9088008528253639
# VAL gen loss = 1.2488635027850117, disc loss = 1.0193840309425637
# Epoch 179, gen loss = 1.48642837953376, disc loss = 0.8627552813794239
# VAL gen loss = 2.133451956289786, disc loss = 0.9490928649902344
# Epoch 180, gen loss = 1.6499677910862198, disc loss = 0.7786533095271712
# VAL gen loss = 1.2539719475640192, disc loss = 0.8983264499240451
# Epoch 181, gen loss = 1.5058527567300453, disc loss = 0.8843245908438441
# VAL gen loss = 0.8868984646267362, disc loss = 1.1124792452211734
# Epoch 182, gen loss = 1.5219407905057731, disc loss = 0.8498861167325552
# VAL gen loss = 2.1492270010489003, disc loss = 0.8792721077247903
# Epoch 183, gen loss = 1.5559645809801708, disc loss = 0.8470911232821913
# VAL gen loss = 0.7572810561568649, disc loss = 1.174928453233507
# Epoch 184, gen loss = 1.4456641262314884, disc loss = 0.8951465039846888
# VAL gen loss = 0.9207163210268374, disc loss = 1.0492014708342376
# Epoch 185, gen loss = 1.486895335247239, disc loss = 0.8736383522370733
# VAL gen loss = 0.8632821683530454, disc loss = 1.059382262053313
# Epoch 186, gen loss = 1.6459721944418297, disc loss = 0.7649147615854042
# VAL gen loss = 1.2115219963921442, disc loss = 0.9410730291295935
# Epoch 187, gen loss = 1.607767128082643, disc loss = 0.7918511203015186
# VAL gen loss = 1.1425116503680195, disc loss = 0.9148952342845775
# Epoch 188, gen loss = 1.657850395723519, disc loss = 0.7527338357335592
# VAL gen loss = 1.4632684213143807, disc loss = 0.9169463404902706
# Epoch 189, gen loss = 1.4888457639150352, disc loss = 0.8922107497372301
# VAL gen loss = 1.30788082546658, disc loss = 1.0035537437156394
# Epoch 190, gen loss = 1.4724979017633033, disc loss = 0.8770957854856928
# VAL gen loss = 1.7253542299623843, disc loss = 0.9758372836642795
# Epoch 191, gen loss = 1.475204896735379, disc loss = 0.8686652738885229
# VAL gen loss = 0.6113556755913628, disc loss = 1.3305347583912037
# Epoch 192, gen loss = 1.5241608523939507, disc loss = 0.8296201774872929
# VAL gen loss = 1.14741939968533, disc loss = 0.955497388486509
# Epoch 193, gen loss = 1.5499770076399348, disc loss = 0.8314585858080761
# VAL gen loss = 1.8951394822862413, disc loss = 0.9983134093108
# Epoch 194, gen loss = 1.5020401429938504, disc loss = 0.8624882832109688
# VAL gen loss = 0.9482888822202329, disc loss = 0.9854390179669416
# Epoch 195, gen loss = 1.5612484116152108, disc loss = 0.8351466167403991
# VAL gen loss = 1.1838743421766493, disc loss = 0.9569124998869719
# Epoch 196, gen loss = 1.6579734465204568, disc loss = 0.764224255420118
# VAL gen loss = 1.1687292169641565, disc loss = 0.98823935897262
# Epoch 197, gen loss = 1.5400231296278866, disc loss = 0.8394362361555597
# VAL gen loss = 1.4680894922327112, disc loss = 0.9396243625217013
# Epoch 198, gen loss = 1.5454601609563252, disc loss = 0.8435531677491215
# VAL gen loss = 1.323246991192853, disc loss = 0.8590331607394748
# Epoch 199, gen loss = 1.6738545980798192, disc loss = 0.7903510403920369
# VAL gen loss = 1.7236001756456163, disc loss = 0.6039901309543185
# Epoch 200, gen loss = 1.820091891001506, disc loss = 0.6712102928314821
# VAL gen loss = 1.3472726609971788, disc loss = 0.8149263593885634
# Epoch 201, gen loss = 1.7676967636169678, disc loss = 0.7011640924047754
# VAL gen loss = 2.0038669727466725, disc loss = 0.8317041043882016
# Epoch 202, gen loss = 1.6437189186433232, disc loss = 0.7857213767178087
# VAL gen loss = 2.0844583864565247, disc loss = 0.8940839414243344
# Epoch 203, gen loss = 1.6395571298867344, disc loss = 0.7774986665411646
# VAL gen loss = 1.5498343573676214, disc loss = 0.8421926145200376
# Epoch 204, gen loss = 1.8232378978805848, disc loss = 0.6930030914674322
# VAL gen loss = 1.1284300486246746, disc loss = 0.8662341082537616
# Epoch 205, gen loss = 1.6742639503325802, disc loss = 0.7816446449861948
# VAL gen loss = 1.495962213586878, disc loss = 0.8651168964527272
# Epoch 206, gen loss = 1.6876089563331451, disc loss = 0.7500753747411522
# VAL gen loss = 1.809356689453125, disc loss = 0.7434074260570385
# Epoch 207, gen loss = 1.6205723774002259, disc loss = 0.8055226276198544
# VAL gen loss = 1.652483339662905, disc loss = 0.9409169091118706
# Epoch 208, gen loss = 1.7685747874309738, disc loss = 0.7238555663082016
# VAL gen loss = 1.0090495215521917, disc loss = 1.010576601381655
# Epoch 209, gen loss = 1.7363742077685742, disc loss = 0.7381991344283384
# VAL gen loss = 1.9614716989022714, disc loss = 0.8285160064697266
# Epoch 210, gen loss = 1.6644461145362701, disc loss = 0.7893111140852472
# VAL gen loss = 1.2848358154296875, disc loss = 0.8068096019603588
# Epoch 211, gen loss = 1.7019971977754769, disc loss = 0.7588341647841366
# VAL gen loss = 1.1786791483561199, disc loss = 0.7924070005063657
# Epoch 212, gen loss = 1.7740610881024097, disc loss = 0.7174503678777611
# VAL gen loss = 1.5554775661892362, disc loss = 0.8531051918312356
# Epoch 213, gen loss = 1.6609439466851783, disc loss = 0.7924949308954569
# VAL gen loss = 1.0051616386131004, disc loss = 1.006660602710865
# Epoch 214, gen loss = 1.6665561170463103, disc loss = 0.7865406940261044
# VAL gen loss = 0.9681841532389323, disc loss = 1.0458143728750724
# Epoch 215, gen loss = 1.627981162932982, disc loss = 0.7821571932260292
# VAL gen loss = 2.0003523649992765, disc loss = 1.2802583199960214
# Epoch 216, gen loss = 1.6692343102880272, disc loss = 0.7937606137440386
# VAL gen loss = 1.1407429730450664, disc loss = 0.890311841611509
# Epoch 217, gen loss = 1.800974405434237, disc loss = 0.7005828489740211
# VAL gen loss = 1.1988936530219183, disc loss = 0.9271478299741391
# Epoch 218, gen loss = 1.730476593875502, disc loss = 0.7579360410391566
# VAL gen loss = 1.605783391881872, disc loss = 0.6738998271800853
# Epoch 219, gen loss = 1.7976956654743976, disc loss = 0.6995133242932668
# VAL gen loss = 1.465046070240162, disc loss = 0.8117251925998263
# Epoch 220, gen loss = 1.8017545033650226, disc loss = 0.7358496485943775
# VAL gen loss = 1.2829177291304976, disc loss = 1.0072643138744213
# Epoch 221, gen loss = 1.8861799738014557, disc loss = 0.6972150687711784
# VAL gen loss = 1.2392924273455586, disc loss = 0.8240760520652488
# Epoch 222, gen loss = 1.7427750552993222, disc loss = 0.7437608098409262
# VAL gen loss = 1.1933362042462383, disc loss = 0.9295404928701895
# Epoch 223, gen loss = 1.7435739049949799, disc loss = 0.7524385873572415
# VAL gen loss = 1.1345032585991754, disc loss = 0.9079539687545212
# Epoch 224, gen loss = 1.73143440461063, disc loss = 0.7436101216388994
# VAL gen loss = 1.3889976784035012, disc loss = 0.8276499995478878
# Epoch 225, gen loss = 1.8055759414611572, disc loss = 0.72520881867313
# VAL gen loss = 1.4051622461389612, disc loss = 0.8540912204318576
# Epoch 226, gen loss = 1.747733855343248, disc loss = 0.7333921869117094
# VAL gen loss = 1.8092053731282551, disc loss = 0.8560617941397207
# Epoch 227, gen loss = 1.7110468240148093, disc loss = 0.7591213241638429
# VAL gen loss = 1.6888899626555267, disc loss = 0.9134056656448929
# Epoch 228, gen loss = 1.7259614630396587, disc loss = 0.7577268301722515
# VAL gen loss = 0.8512575361463759, disc loss = 1.0818119049072266
# Epoch 229, gen loss = 1.6839861888962098, disc loss = 0.7893457374419554
# VAL gen loss = 0.8717527742739077, disc loss = 1.0345790297896773
# Epoch 230, gen loss = 1.722610044670871, disc loss = 0.7516500940284576
# VAL gen loss = 0.831427256266276, disc loss = 1.0695482889811199
# Epoch 231, gen loss = 1.6466649066971009, disc loss = 0.8115338551471512
# VAL gen loss = 1.0685608475296586, disc loss = 0.9923708173963759
# Epoch 232, gen loss = 1.6179189413905624, disc loss = 0.8129466106613956
# VAL gen loss = 1.330511587637442, disc loss = 0.8312646371346933
# Epoch 233, gen loss = 1.6701064511954067, disc loss = 0.7854608742587538
# VAL gen loss = 1.3528982091833044, disc loss = 0.7455822273536965
# Epoch 234, gen loss = 1.6575738991120732, disc loss = 0.7798107714059362
# VAL gen loss = 1.197379924632885, disc loss = 0.9032140661168981
# Epoch 235, gen loss = 1.6409000258847892, disc loss = 0.7984034526778991
# VAL gen loss = 1.403485616048177, disc loss = 0.9479288171838831
# Epoch 236, gen loss = 1.7337852386106927, disc loss = 0.7548853862716491
# VAL gen loss = 1.5172641895435475, disc loss = 0.7977185425934968
# Epoch 237, gen loss = 1.7538486465392822, disc loss = 0.7462360428040287
# VAL gen loss = 1.997428328902633, disc loss = 0.883085674709744
# Epoch 238, gen loss = 1.8087849444653614, disc loss = 0.7047211061041039
# VAL gen loss = 1.2857432895236545, disc loss = 0.8530629475911459
# Epoch 239, gen loss = 1.811051701924887, disc loss = 0.7123463335764935
# VAL gen loss = 1.2271701671459057, disc loss = 0.9355156509964554
# Epoch 240, gen loss = 1.7759762193304467, disc loss = 0.7299207817598519
# VAL gen loss = 1.1433707343207464, disc loss = 0.9586163979989512
# Epoch 241, gen loss = 1.7316206966538028, disc loss = 0.7617846262981613
# VAL gen loss = 1.0546565585666232, disc loss = 0.9497299194335938
# Epoch 242, gen loss = 1.7243912172126004, disc loss = 0.7448535597467997
# VAL gen loss = 1.220344967312283, disc loss = 1.008267084757487
# Epoch 243, gen loss = 1.6190391448606927, disc loss = 0.8148474023045307
# VAL gen loss = 1.346115960015191, disc loss = 0.8991969073260272
# Epoch 244, gen loss = 1.6911728947038152, disc loss = 0.7979197061684237
# VAL gen loss = 2.115785386827257, disc loss = 0.8957714504665799
# Epoch 245, gen loss = 1.7783809799745858, disc loss = 0.7182531395111696
# VAL gen loss = 1.0168923978452329, disc loss = 0.9827456297697844
# Epoch 246, gen loss = 1.7615202019013554, disc loss = 0.7238700897339357
# VAL gen loss = 2.1388733475296586, disc loss = 0.9017040111400463
# Epoch 247, gen loss = 1.7709495207392068, disc loss = 0.7337197299941955
# VAL gen loss = 1.819695931893808, disc loss = 0.767769354361075
# Epoch 248, gen loss = 1.8189833307840737, disc loss = 0.7062004119995607
# VAL gen loss = 1.4397072968659577, disc loss = 0.7967293350784866
# Epoch 249, gen loss = 1.8305698379455322, disc loss = 0.6889524651339733
# VAL gen loss = 2.168770684136285, disc loss = 0.6790349041974103

# %%
plt.plot(hist[0], c='r', label='g_loss')
plt.plot(hist[3], c='b', label='val_g_loss') 
plt.legend()
plt.xlabel('epochs')
plt.ylabel('generator loss')
plt.show()

# %%
plt.plot(hist[1], c='r', label='d_loss')
plt.plot(hist[4], c='b', label='val_d_loss') 
plt.legend()
plt.xlabel('epochs')
plt.ylabel('discriminator loss')
plt.show()

# %% [markdown]
# # Zip images for download

# %%
# !zip -r images.zip "/kaggle/working/generated2/"
# Out:
#   adding: kaggle/working/generated2/ (stored 0%)
#   adding: kaggle/working/generated2/train-112.png (deflated 0%)
#   adding: kaggle/working/generated2/train-38.png (deflated 0%)
#   adding: kaggle/working/generated2/train-85.png (deflated 0%)
#   adding: kaggle/working/generated2/train-3.png (deflated 0%)
#   adding: kaggle/working/generated2/train-176.png (deflated 0%)
#   adding: kaggle/working/generated2/train-122.png (deflated 0%)
#   adding: kaggle/working/generated2/train-28.png (deflated 0%)
#   adding: kaggle/working/generated2/train-124.png (deflated 0%)
#   adding: kaggle/working/generated2/train-67.png (deflated 0%)
#   adding: kaggle/working/generated2/train-173.png (deflated 0%)
#   adding: kaggle/working/generated2/train-6.png (deflated 0%)
#   adding: kaggle/working/generated2/train-31.png (deflated 0%)
#   adding: kaggle/working/generated2/train-186.png (deflated 0%)
#   adding: kaggle/working/generated2/train-183.png (deflated 0%)
#   adding: kaggle/working/generated2/train-119.png (deflated 0%)
#   adding: kaggle/working/generated2/train-169.png (deflated 0%)
#   adding: kaggle/working/generated2/train-135.png (deflated 0%)
#   adding: kaggle/working/generated2/train-131.png (deflated 0%)
#   adding: kaggle/working/generated2/train-19.png (deflated 0%)
#   adding: kaggle/working/generated2/train-12.png (deflated 0%)
#   adding: kaggle/working/generated2/train-162.png (deflated 0%)
#   adding: kaggle/working/generated2/train-46.png (deflated 0%)
#   adding: kaggle/working/generated2/train-145.png (deflated 0%)
#   adding: kaggle/working/generated2/train-1.png (deflated 0%)
#   adding: kaggle/working/generated2/train-11.png (deflated 0%)
#   adding: kaggle/working/generated2/train-121.png (deflated 0%)
#   adding: kaggle/working/generated2/train-95.png (deflated 0%)
#   adding: kaggle/working/generated2/train-243.png (deflated 0%)
#   adding: kaggle/working/generated2/train-77.png (deflated 0%)
#   adding: kaggle/working/generated2/train-167.png (deflated 0%)
#   adding: kaggle/working/generated2/train-239.png (deflated 0%)
#   adding: kaggle/working/generated2/train-201.png (deflated 0%)
#   adding: kaggle/working/generated2/train-128.png (deflated 0%)
#   adding: kaggle/working/generated2/train-223.png (deflated 0%)
#   adding: kaggle/working/generated2/train-179.png (deflated 0%)
#   adding: kaggle/working/generated2/train-127.png (deflated 0%)
#   adding: kaggle/working/generated2/train-193.png (deflated 0%)
#   adding: kaggle/working/generated2/train-231.png (deflated 0%)
#   adding: kaggle/working/generated2/train-248.png (deflated 0%)
#   adding: kaggle/working/generated2/train-203.png (deflated 0%)
#   adding: kaggle/working/generated2/train-136.png (deflated 0%)
#   adding: kaggle/working/generated2/train-142.png (deflated 0%)
#   adding: kaggle/working/generated2/train-192.png (deflated 0%)
#   adding: kaggle/working/generated2/train-51.png (deflated 0%)
#   adding: kaggle/working/generated2/train-101.png (deflated 0%)
#   adding: kaggle/working/generated2/train-2.png (deflated 0%)
#   adding: kaggle/working/generated2/train-61.png (deflated 0%)
#   adding: kaggle/working/generated2/train-200.png (deflated 0%)
#   adding: kaggle/working/generated2/train-180.png (deflated 0%)
#   adding: kaggle/working/generated2/train-113.png (deflated 0%)
#   adding: kaggle/working/generated2/train-126.png (deflated 0%)
#   adding: kaggle/working/generated2/train-26.png (deflated 0%)
#   adding: kaggle/working/generated2/train-80.png (deflated 0%)
#   adding: kaggle/working/generated2/train-79.png (deflated 0%)
#   adding: kaggle/working/generated2/train-107.png (deflated 0%)
#   adding: kaggle/working/generated2/train-148.png (deflated 0%)
#   adding: kaggle/working/generated2/train-32.png (deflated 0%)
#   adding: kaggle/working/generated2/train-115.png (deflated 0%)
#   adding: kaggle/working/generated2/train-134.png (deflated 0%)
#   adding: kaggle/working/generated2/train-210.png (deflated 0%)
#   adding: kaggle/working/generated2/train-34.png (deflated 0%)
#   adding: kaggle/working/generated2/train-103.png (deflated 0%)
#   adding: kaggle/working/generated2/train-197.png (deflated 0%)
#   adding: kaggle/working/generated2/train-7.png (deflated 0%)
#   adding: kaggle/working/generated2/train-40.png (deflated 0%)
#   adding: kaggle/working/generated2/train-62.png (deflated 0%)
#   adding: kaggle/working/generated2/train-211.png (deflated 0%)
#   adding: kaggle/working/generated2/train-204.png (deflated 0%)
#   adding: kaggle/working/generated2/train-17.png (deflated 0%)
#   adding: kaggle/working/generated2/train-65.png (deflated 0%)
#   adding: kaggle/working/generated2/train-224.png (deflated 0%)
#   adding: kaggle/working/generated2/train-78.png (deflated 0%)
#   adding: kaggle/working/generated2/train-190.png (deflated 0%)
#   adding: kaggle/working/generated2/train-144.png (deflated 0%)
#   adding: kaggle/working/generated2/train-218.png (deflated 0%)
#   adding: kaggle/working/generated2/train-106.png (deflated 0%)
#   adding: kaggle/working/generated2/train-242.png (deflated 0%)
#   adding: kaggle/working/generated2/train-22.png (deflated 0%)
#   adding: kaggle/working/generated2/train-172.png (deflated 0%)
#   adding: kaggle/working/generated2/train-195.png (deflated 0%)
#   adding: kaggle/working/generated2/train-88.png (deflated 0%)
#   adding: kaggle/working/generated2/train-50.png (deflated 0%)
#   adding: kaggle/working/generated2/train-191.png (deflated 0%)
#   adding: kaggle/working/generated2/train-133.png (deflated 0%)
#   adding: kaggle/working/generated2/train-35.png (deflated 0%)
#   adding: kaggle/working/generated2/train-15.png (deflated 0%)
#   adding: kaggle/working/generated2/train-156.png (deflated 0%)
#   adding: kaggle/working/generated2/train-205.png (deflated 0%)
#   adding: kaggle/working/generated2/train-244.png (deflated 0%)
#   adding: kaggle/working/generated2/train-228.png (deflated 0%)
#   adding: kaggle/working/generated2/train-76.png (deflated 0%)
#   adding: kaggle/working/generated2/train-66.png (deflated 0%)
#   adding: kaggle/working/generated2/train-27.png (deflated 0%)
#   adding: kaggle/working/generated2/train-81.png (deflated 0%)
#   adding: kaggle/working/generated2/train-146.png (deflated 0%)
#   adding: kaggle/working/generated2/train-102.png (deflated 0%)
#   adding: kaggle/working/generated2/train-151.png (deflated 0%)
#   adding: kaggle/working/generated2/train-125.png (deflated 0%)
#   adding: kaggle/working/generated2/train-0.png (deflated 0%)
#   adding: kaggle/working/generated2/train-33.png (deflated 0%)
#   adding: kaggle/working/generated2/train-123.png (deflated 0%)
#   adding: kaggle/working/generated2/train-141.png (deflated 0%)
#   adding: kaggle/working/generated2/train-234.png (deflated 0%)
#   adding: kaggle/working/generated2/train-153.png (deflated 0%)
#   adding: kaggle/working/generated2/train-202.png (deflated 0%)
#   adding: kaggle/working/generated2/train-150.png (deflated 0%)
#   adding: kaggle/working/generated2/train-83.png (deflated 0%)
#   adding: kaggle/working/generated2/train-30.png (deflated 0%)
#   adding: kaggle/working/generated2/train-174.png (deflated 0%)
#   adding: kaggle/working/generated2/train-160.png (deflated 0%)
#   adding: kaggle/working/generated2/train-236.png (deflated 0%)
#   adding: kaggle/working/generated2/train-23.png (deflated 0%)
#   adding: kaggle/working/generated2/train-116.png (deflated 0%)
#   adding: kaggle/working/generated2/train-171.png (deflated 0%)
#   adding: kaggle/working/generated2/train-47.png (deflated 0%)
#   adding: kaggle/working/generated2/train-225.png (deflated 0%)
#   adding: kaggle/working/generated2/train-147.png (deflated 0%)
#   adding: kaggle/working/generated2/train-52.png (deflated 0%)
#   adding: kaggle/working/generated2/train-139.png (deflated 0%)
#   adding: kaggle/working/generated2/train-164.png (deflated 0%)
#   adding: kaggle/working/generated2/train-240.png (deflated 0%)
#   adding: kaggle/working/generated2/train-163.png (deflated 0%)
#   adding: kaggle/working/generated2/train-10.png (deflated 0%)
#   adding: kaggle/working/generated2/train-53.png (deflated 0%)
#   adding: kaggle/working/generated2/train-194.png (deflated 0%)
#   adding: kaggle/working/generated2/train-157.png (deflated 0%)
#   adding: kaggle/working/generated2/train-222.png (deflated 0%)
#   adding: kaggle/working/generated2/train-63.png (deflated 0%)
#   adding: kaggle/working/generated2/train-96.png (deflated 0%)
#   adding: kaggle/working/generated2/train-215.png (deflated 0%)
#   adding: kaggle/working/generated2/train-70.png (deflated 0%)
#   adding: kaggle/working/generated2/train-97.png (deflated 0%)
#   adding: kaggle/working/generated2/train-36.png (deflated 0%)
#   adding: kaggle/working/generated2/train-220.png (deflated 0%)
#   adding: kaggle/working/generated2/train-235.png (deflated 0%)
#   adding: kaggle/working/generated2/train-143.png (deflated 0%)
#   adding: kaggle/working/generated2/train-100.png (deflated 0%)
#   adding: kaggle/working/generated2/train-42.png (deflated 0%)
#   adding: kaggle/working/generated2/train-64.png (deflated 0%)
#   adding: kaggle/working/generated2/train-168.png (deflated 0%)
#   adding: kaggle/working/generated2/train-130.png (deflated 0%)
#   adding: kaggle/working/generated2/train-39.png (deflated 0%)
#   adding: kaggle/working/generated2/train-72.png (deflated 0%)
#   adding: kaggle/working/generated2/train-105.png (deflated 0%)
#   adding: kaggle/working/generated2/train-41.png (deflated 0%)
#   adding: kaggle/working/generated2/train-56.png (deflated 0%)
#   adding: kaggle/working/generated2/train-238.png (deflated 0%)
#   adding: kaggle/working/generated2/train-155.png (deflated 0%)
#   adding: kaggle/working/generated2/train-229.png (deflated 0%)
#   adding: kaggle/working/generated2/train-214.png (deflated 0%)
#   adding: kaggle/working/generated2/train-114.png (deflated 0%)
#   adding: kaggle/working/generated2/train-161.png (deflated 0%)
#   adding: kaggle/working/generated2/train-29.png (deflated 0%)
#   adding: kaggle/working/generated2/train-178.png (deflated 0%)
#   adding: kaggle/working/generated2/train-237.png (deflated 0%)
#   adding: kaggle/working/generated2/train-212.png (deflated 0%)
#   adding: kaggle/working/generated2/train-184.png (deflated 0%)
#   adding: kaggle/working/generated2/train-55.png (deflated 0%)
#   adding: kaggle/working/generated2/train-109.png (deflated 0%)
#   adding: kaggle/working/generated2/train-8.png (deflated 0%)
#   adding: kaggle/working/generated2/train-166.png (deflated 0%)
#   adding: kaggle/working/generated2/train-230.png (deflated 0%)
#   adding: kaggle/working/generated2/train-221.png (deflated 0%)
#   adding: kaggle/working/generated2/train-43.png (deflated 0%)
#   adding: kaggle/working/generated2/train-182.png (deflated 0%)
#   adding: kaggle/working/generated2/train-25.png (deflated 0%)
#   adding: kaggle/working/generated2/train-209.png (deflated 0%)
#   adding: kaggle/working/generated2/train-49.png (deflated 0%)
#   adding: kaggle/working/generated2/train-189.png (deflated 0%)
#   adding: kaggle/working/generated2/train-117.png (deflated 0%)
#   adding: kaggle/working/generated2/train-170.png (deflated 0%)
#   adding: kaggle/working/generated2/train-21.png (deflated 0%)
#   adding: kaggle/working/generated2/train-69.png (deflated 0%)
#   adding: kaggle/working/generated2/train-227.png (deflated 0%)
#   adding: kaggle/working/generated2/train-152.png (deflated 0%)
#   adding: kaggle/working/generated2/train-165.png (deflated 0%)
#   adding: kaggle/working/generated2/train-185.png (deflated 0%)
#   adding: kaggle/working/generated2/train-20.png (deflated 0%)
#   adding: kaggle/working/generated2/train-245.png (deflated 0%)
#   adding: kaggle/working/generated2/train-159.png (deflated 0%)
#   adding: kaggle/working/generated2/train-16.png (deflated 0%)
#   adding: kaggle/working/generated2/train-246.png (deflated 0%)
#   adding: kaggle/working/generated2/train-14.png (deflated 0%)
#   adding: kaggle/working/generated2/train-60.png (deflated 0%)
#   adding: kaggle/working/generated2/train-181.png (deflated 0%)
#   adding: kaggle/working/generated2/train-37.png (deflated 0%)
#   adding: kaggle/working/generated2/train-59.png (deflated 0%)
#   adding: kaggle/working/generated2/train-241.png (deflated 0%)
#   adding: kaggle/working/generated2/train-89.png (deflated 0%)
#   adding: kaggle/working/generated2/train-45.png (deflated 0%)
#   adding: kaggle/working/generated2/train-206.png (deflated 0%)
#   adding: kaggle/working/generated2/train-158.png (deflated 0%)
#   adding: kaggle/working/generated2/train-44.png (deflated 0%)
#   adding: kaggle/working/generated2/train-18.png (deflated 0%)
#   adding: kaggle/working/generated2/train-129.png (deflated 0%)
#   adding: kaggle/working/generated2/train-24.png (deflated 0%)
#   adding: kaggle/working/generated2/train-233.png (deflated 0%)
#   adding: kaggle/working/generated2/train-232.png (deflated 0%)
#   adding: kaggle/working/generated2/train-175.png (deflated 0%)
#   adding: kaggle/working/generated2/train-94.png (deflated 0%)
#   adding: kaggle/working/generated2/train-90.png (deflated 0%)
#   adding: kaggle/working/generated2/train-58.png (deflated 0%)
#   adding: kaggle/working/generated2/train-48.png (deflated 0%)
#   adding: kaggle/working/generated2/train-57.png (deflated 0%)
#   adding: kaggle/working/generated2/train-187.png (deflated 0%)
#   adding: kaggle/working/generated2/train-198.png (deflated 0%)
#   adding: kaggle/working/generated2/train-196.png (deflated 0%)
#   adding: kaggle/working/generated2/train-217.png (deflated 0%)
#   adding: kaggle/working/generated2/train-91.png (deflated 0%)
#   adding: kaggle/working/generated2/train-9.png (deflated 0%)
#   adding: kaggle/working/generated2/train-118.png (deflated 0%)
#   adding: kaggle/working/generated2/train-219.png (deflated 0%)
#   adding: kaggle/working/generated2/train-5.png (deflated 0%)
#   adding: kaggle/working/generated2/train-132.png (deflated 0%)
#   adding: kaggle/working/generated2/train-137.png (deflated 0%)
#   adding: kaggle/working/generated2/train-111.png (deflated 0%)
#   adding: kaggle/working/generated2/train-84.png (deflated 0%)
#   adding: kaggle/working/generated2/train-93.png (deflated 0%)
#   adding: kaggle/working/generated2/train-74.png (deflated 0%)
#   adding: kaggle/working/generated2/train-75.png (deflated 0%)
#   adding: kaggle/working/generated2/train-208.png (deflated 0%)
#   adding: kaggle/working/generated2/train-247.png (deflated 0%)
#   adding: kaggle/working/generated2/train-199.png (deflated 0%)
#   adding: kaggle/working/generated2/train-188.png (deflated 0%)
#   adding: kaggle/working/generated2/train-87.png (deflated 0%)
#   adding: kaggle/working/generated2/train-86.png (deflated 0%)
#   adding: kaggle/working/generated2/train-108.png (deflated 0%)
#   adding: kaggle/working/generated2/train-13.png (deflated 0%)
#   adding: kaggle/working/generated2/train-213.png (deflated 0%)
#   adding: kaggle/working/generated2/train-68.png (deflated 0%)
#   adding: kaggle/working/generated2/train-207.png (deflated 0%)
#   adding: kaggle/working/generated2/train-138.png (deflated 0%)
#   adding: kaggle/working/generated2/train-98.png (deflated 0%)
#   adding: kaggle/working/generated2/train-216.png (deflated 0%)
#   adding: kaggle/working/generated2/train-149.png (deflated 0%)
#   adding: kaggle/working/generated2/train-54.png (deflated 0%)
#   adding: kaggle/working/generated2/train-249.png (deflated 0%)
#   adding: kaggle/working/generated2/train-82.png (deflated 0%)
#   adding: kaggle/working/generated2/train-154.png (deflated 0%)
#   adding: kaggle/working/generated2/train-177.png (deflated 0%)
#   adding: kaggle/working/generated2/train-104.png (deflated 0%)
#   adding: kaggle/working/generated2/train-99.png (deflated 0%)
#   adding: kaggle/working/generated2/train-4.png (deflated 0%)
#   adding: kaggle/working/generated2/train-71.png (deflated 0%)
#   adding: kaggle/working/generated2/train-140.png (deflated 0%)
#   adding: kaggle/working/generated2/train-73.png (deflated 0%)
#   adding: kaggle/working/generated2/train-110.png (deflated 0%)
#   adding: kaggle/working/generated2/train-92.png (deflated 0%)
#   adding: kaggle/working/generated2/train-120.png (deflated 0%)
#   adding: kaggle/working/generated2/train-226.png (deflated 0%)

# %%
from IPython.display import FileLink
FileLink(r'images.zip')
# Out:
# /content/drive/My Drive/Project/WGAN art/dataset_updated/images.zip

# %% [markdown]
# # printing a random set of pictures generated by the trained generator
#
# Just for playing with it to see what we find, generates a new seed everytime

# %%
seed2 = tf.random.normal([BATCH_SIZE, SEED_SIZE])
generated_images2 = generator(seed2, training = True)

generated_images2 =0.5 * generated_images2 + 0.5

fig = plt.figure(figsize=(10,10))
for i in range(1,21):
    fig.add_subplot(5,5,i)
    plt.imshow(generated_images2[i])
    plt.axis('off')

# %% [markdown]
# ##starting

# %%
noise = tf.random.normal([BATCH_SIZE, SEED_SIZE])
generated_images = generator(noise, training=False)

# %%
val_img = np.zeros((BATCH_SIZE, 75, 75, 3))
val_img[:, :64, :64, :] = next(iter(training_dataset))
val_dataset = tf.data.Dataset.from_tensor_slices(val_img).shuffle(9000).batch(BATCH_SIZE)

# %%
val_gen_img = np.zeros((BATCH_SIZE, 75, 75, 3))
val_gen_img[:, :64, :64, :] = generated_images
val_dataset_gen = tf.data.Dataset.from_tensor_slices(val_gen_img).shuffle(9000).batch(BATCH_SIZE)

# %%
inception_model = tf.keras.applications.InceptionV3(include_top=False, input_shape=val_img.shape[1:], weights="imagenet", pooling='avg')

# %%
from tqdm import tqdm
def compute_embeddings(dataloader, count):
    image_embeddings = []

    for _ in tqdm(range(count)):
        images = next(iter(dataloader))
        embeddings = inception_model.predict(images)

        image_embeddings.extend(embeddings)

    return np.array(image_embeddings)

count = math.ceil(10000/BATCH_SIZE)

# compute embeddings for real images
real_image_embeddings = compute_embeddings(val_dataset, count)

# compute embeddings for generated images
generated_image_embeddings = compute_embeddings(val_dataset_gen, count)

real_image_embeddings.shape, generated_image_embeddings.shape
# Out:
# 100%|██████████| 313/313 [00:35<00:00,  8.86it/s]
# 100%|██████████| 313/313 [00:33<00:00,  9.30it/s]
# ((10016, 2048), (10016, 2048))

# %%
from scipy.linalg import sqrtm

def calculate_fid(real_embeddings, generated_embeddings):
    # calculate mean and covariance statistics
    mu1, sigma1 = real_embeddings.mean(axis=0), np.cov(real_embeddings, rowvar=False)
    mu2, sigma2 = generated_embeddings.mean(axis=0), np.cov(generated_embeddings,  rowvar=False)
    
    # calculate sum squared difference between means
    ssdiff = np.sum((mu1 - mu2)**2.0)
    
    # calculate sqrt of product between cov
    covmean = sqrtm(sigma1.dot(sigma2))
    
    # check and correct imaginary numbers from sqrt
    if np.iscomplexobj(covmean):
        covmean = covmean.real
    
    # calculate score
    fid = ssdiff + np.trace(sigma1 + sigma2 - 2.0 * covmean)
    
    return fid

fid = calculate_fid(real_image_embeddings, generated_image_embeddings)
fid
